# %%
# %cd /content/drive/MyDrive/SRGAN
# Out:
# /content/drive/MyDrive/SRGAN

# %%
# !git clone https://github.com/xinntao/ESRGAN.git
# Out:
# Cloning into 'ESRGAN'...
# remote: Enumerating objects: 225, done.
# remote: Total 225 (delta 0), reused 0 (delta 0), pack-reused 225
# Receiving objects: 100% (225/225), 24.86 MiB | 17.79 MiB/s, done.
# Resolving deltas: 100% (86/86), done.

# %%
# %cd ESRGAN
# Out:
# /content/drive/MyDrive/SRGAN/ESRGAN

# %%
# !python test.py
# Out:
# Model path models/RRDB_ESRGAN_x4.pth.
# Testing...
# 1 comic
# 2 my-image
# 3 baboon
